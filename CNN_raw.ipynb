# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Folder where segmented .npy files are saved
data_folder = '/Users/aidantang/Desktop/Gesture_recog/raw_data_ungrouped'
# Files are assumed to be named: S1_segmented.npy, S2_segmented.npy, ..., S11_segmented.npy
patient_ids = range(1, 12)

# Set total number of classes (stimulus labels 1 to 17)
total_classes = 17

# --------------------------
# Define the CNN architecture (using only the EMG signal)
# --------------------------
def build_cnn(input_shape, num_classes):
    """
    Builds a CNN with three convolutional blocks.
    Expects input_shape = (400, 12) where 400 is the number of time steps and 12 are the EMG channels.
    """
    model = Sequential()
    # Block 1
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu',
                     kernel_regularizer=l2(0.001), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    
    # Block 2
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu',
                     kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    
    # Block 3
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu',
                     kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    
    # Classification head
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# --------------------------
# Callbacks for training
# --------------------------
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=1)

# --------------------------
# Process each patient separately (new CNN for each)
# --------------------------
results = []  # This list will store one dictionary per patient

for patient_id in patient_ids:
    file_path = os.path.join(data_folder, f'S{patient_id}_segmented.npy')
    if not os.path.exists(file_path):
        print(f"Segmented file not found for patient {patient_id}: {file_path}")
        continue
    print(f"\nProcessing patient {patient_id}")
    # Load the segmented data; expected shape: (num_segments, 400, 17)
    segments = np.load(file_path)
    print("Loaded segmented data shape:", segments.shape)
    
    # Extract metadata from the first segment (assumed constant for patient)
    if segments.shape[0] > 0:
        forearm_percentage = segments[0, 0, 0]  # from column 0
        years_since_amputation = segments[0, 0, 1]  # from column 1
        myoelectric_use = segments[0, 0, 2]  # from column 2
    else:
        forearm_percentage = years_since_amputation = myoelectric_use = np.nan
    
    # Extract target labels and repetition information from metadata.
    # Column 3: Stimulus, Column 4: Repetition.
    y_all = segments[:, 0, 3]    # stimulus from first time step of each segment
    reps_all = segments[:, 0, 4] # repetition from first time step of each segment

    # Drop segments where stimulus == 0
    valid_idx = np.where(y_all != 0)[0]
    segments = segments[valid_idx]
    y_all = y_all[valid_idx]
    reps_all = reps_all[valid_idx]
    print("After dropping stimulus 0, segments shape:", segments.shape)
    
    # Use only the EMG signal: columns 5 to 16.
    # This gives input shape: (num_segments, 400, 12)
    X_all = segments[:, :, 5:17]
    
    # Split the data based on repetition values:
    # Use repetition values [1, 3, 5] for training, [2, 4] for validation, and 6 for testing.
    train_idx = np.where(np.isin(reps_all, [1, 3, 5]))[0]
    val_idx   = np.where(np.isin(reps_all, [2, 4]))[0]
    test_idx  = np.where(reps_all == 6)[0]
    
    X_train = X_all[train_idx]
    X_val   = X_all[val_idx]
    X_test  = X_all[test_idx]
    
    y_train = y_all[train_idx]
    y_val   = y_all[val_idx]
    y_test  = y_all[test_idx]
    
    print("Train X shape:", X_train.shape)
    print("Val X shape:", X_val.shape)
    print("Test X shape:", X_test.shape)
    
    # Convert labels to categorical (subtract 1 so that class 1 maps to index 0)
    y_train_cat = to_categorical(y_train - 1, num_classes=total_classes)
    y_val_cat   = to_categorical(y_val - 1, num_classes=total_classes)
    y_test_cat  = to_categorical(y_test - 1, num_classes=total_classes)
    
    # Initialize a new CNN model for this patient.
    input_shape = X_train.shape[1:]  # (400, 12)
    print("Initializing model with input shape:", input_shape)
    model = build_cnn(input_shape=input_shape, num_classes=total_classes)
    
    # Train the model.
    model.fit(X_train, y_train_cat,
              epochs=20,
              batch_size=32,
              validation_data=(X_val, y_val_cat),
              callbacks=[early_stopping, checkpoint, reduce_lr],
              verbose=1)
    
    # Optional fine-tuning on validation data with a lower learning rate.
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_val, y_val_cat, epochs=5, batch_size=32, verbose=1)
    
    # Evaluate on the test set.
    test_loss, test_accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
    print(f"Patient {patient_id} test accuracy: {test_accuracy:.4f}")
    
    # Plot a normalized confusion matrix.
    y_pred = np.argmax(model.predict(X_test), axis=1)
    y_true = np.argmax(y_test_cat, axis=1)
    display_labels = list(range(1, total_classes + 1))  # labels 1 to 17
    cm = confusion_matrix(y_true, y_pred, normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
    fig, ax = plt.subplots(figsize=(10, 10))
    disp.plot(cmap='viridis', values_format=".2f", ax=ax)
    plt.title(f"Normalized Confusion Matrix - Patient {patient_id}")
    plt.show()
    
    # Append patient results to the results list.
    results.append({
        'PatientID': patient_id,
        'TestAccuracy': test_accuracy,
        'Years_Since_Amputation': years_since_amputation,
        'Forearm_Percentage': forearm_percentage,
        'Myoelectric_Use': myoelectric_use
    })
    
    print(f"Patient {patient_id} test accuracy: {test_accuracy:.4f}\n")

print("Processing complete for all patients.")
# Out:
# Processing patient 1
# Loaded segmented data shape: (9124, 400, 17)
# After dropping stimulus 0, segments shape: (5483, 400, 17)
# Train X shape: (2730, 400, 12)
# Val X shape: (1828, 400, 12)
# Test X shape: (925, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0824 - loss: 3.8973
# Epoch 1: val_loss improved from inf to 3.36470, saving model to best_model.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.0826 - loss: 3.8905 - val_accuracy: 0.0946 - val_loss: 3.3647 - learning_rate: 0.0010
# Epoch 2/20
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2012 - loss: 2.6033
# Epoch 2: val_loss did not improve from 3.36470
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.2017 - loss: 2.6021 - val_accuracy: 0.1400 - val_loss: 4.2235 - learning_rate: 0.0010
# Epoch 3/20
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3440 - loss: 2.1725
# Epoch 3: val_loss did not improve from 3.36470
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3442 - loss: 2.1720 - val_accuracy: 0.1822 - val_loss: 3.4288 - learning_rate: 0.0010
# Epoch 4/20
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4939 - loss: 1.7127
# Epoch 4: val_loss improved from 3.36470 to 2.94465, saving model to best_model.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4944 - loss: 1.7112 - val_accuracy: 0.2396 - val_loss: 2.9446 - learning_rate: 5.0000e-04
# Epoch 5/20
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5793 - loss: 1.3985
# Epoch 5: val_loss did not improve from 2.94465
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5793 - loss: 1.3983 - val_accuracy: 0.2500 - val_loss: 2.9740 - learning_rate: 5.0000e-04
# Epoch 6/20
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7017 - loss: 1.0673
# Epoch 6: val_loss did not improve from 2.94465
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7015 - loss: 1.0677 - val_accuracy: 0.2735 - val_loss: 3.0819 - learning_rate: 5.0000e-04
# Epoch 7/20
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7626 - loss: 0.8903
# Epoch 7: val_loss improved from 2.94465 to 2.77333, saving model to best_model.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7627 - loss: 0.8901 - val_accuracy: 0.2927 - val_loss: 2.7733 - learning_rate: 2.5000e-04
# Epoch 8/20
# 82/86 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7927 - loss: 0.7684
# Epoch 8: val_loss improved from 2.77333 to 2.70077, saving model to best_model.keras
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7928 - loss: 0.7682 - val_accuracy: 0.3042 - val_loss: 2.7008 - learning_rate: 2.5000e-04
# Epoch 9/20
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8377 - loss: 0.6386
# Epoch 9: val_loss did not improve from 2.70077
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8375 - loss: 0.6390 - val_accuracy: 0.3058 - val_loss: 2.7133 - learning_rate: 2.5000e-04
# Epoch 10/20
# 83/86 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8540 - loss: 0.6046
# Epoch 10: val_loss did not improve from 2.70077
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8540 - loss: 0.6040 - val_accuracy: 0.2949 - val_loss: 2.7846 - learning_rate: 2.5000e-04
# Epoch 11/20
# 83/86 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8716 - loss: 0.5295
# Epoch 11: val_loss did not improve from 2.70077
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8716 - loss: 0.5298 - val_accuracy: 0.3042 - val_loss: 2.8419 - learning_rate: 1.2500e-04
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.2313 - loss: 2.9338
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4001 - loss: 1.9134
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5389 - loss: 1.4449
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6053 - loss: 1.2339
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6878 - loss: 1.0624
# Patient 1 test accuracy: 0.3362
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Patient 1 test accuracy: 0.3362
#
#
# Processing patient 2
# Loaded segmented data shape: (8877, 400, 17)
# After dropping stimulus 0, segments shape: (4158, 400, 17)
# Train X shape: (2147, 400, 12)
# Val X shape: (1366, 400, 12)
# Test X shape: (645, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 65/68 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0831 - loss: 3.8667
# Epoch 1: val_loss did not improve from 2.70077
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.0841 - loss: 3.8307 - val_accuracy: 0.1259 - val_loss: 2.7895 - learning_rate: 0.0010
# Epoch 2/20
# 66/68 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2178 - loss: 2.5613
# Epoch 2: val_loss improved from 2.70077 to 2.57821, saving model to best_model.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.2183 - loss: 2.5607 - val_accuracy: 0.2006 - val_loss: 2.5782 - learning_rate: 0.0010
# Epoch 3/20
# 65/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3179 - loss: 2.2162
# Epoch 3: val_loss improved from 2.57821 to 2.41450, saving model to best_model.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3181 - loss: 2.2158 - val_accuracy: 0.2592 - val_loss: 2.4145 - learning_rate: 0.0010
# Epoch 4/20
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4355 - loss: 1.8456
# Epoch 4: val_loss improved from 2.41450 to 2.34630, saving model to best_model.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4347 - loss: 1.8470 - val_accuracy: 0.2731 - val_loss: 2.3463 - learning_rate: 0.0010
# Epoch 5/20
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5074 - loss: 1.6284
# Epoch 5: val_loss improved from 2.34630 to 2.30288, saving model to best_model.keras
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5075 - loss: 1.6282 - val_accuracy: 0.3060 - val_loss: 2.3029 - learning_rate: 0.0010
# Epoch 6/20
# 65/68 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5909 - loss: 1.3237
# Epoch 6: val_loss did not improve from 2.30288
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5905 - loss: 1.3270 - val_accuracy: 0.2921 - val_loss: 2.4024 - learning_rate: 0.0010
# Epoch 7/20
# 67/68 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6590 - loss: 1.1453
# Epoch 7: val_loss did not improve from 2.30288
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6585 - loss: 1.1457 - val_accuracy: 0.3089 - val_loss: 2.4974 - learning_rate: 0.0010
# Epoch 8/20
# 66/68 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7088 - loss: 0.9644
# Epoch 8: val_loss did not improve from 2.30288
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7086 - loss: 0.9645 - val_accuracy: 0.3038 - val_loss: 2.4446 - learning_rate: 5.0000e-04
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2328 - loss: 2.6502
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3433 - loss: 2.1110
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4750 - loss: 1.6654
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5003 - loss: 1.6191
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6075 - loss: 1.3009
# Patient 2 test accuracy: 0.3271
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Patient 2 test accuracy: 0.3271
#
#
# Processing patient 3
# Loaded segmented data shape: (9007, 400, 17)
# After dropping stimulus 0, segments shape: (3597, 400, 17)
# Train X shape: (1810, 400, 12)
# Val X shape: (1188, 400, 12)
# Test X shape: (599, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.0673 - loss: 4.0155
# Epoch 1: val_loss did not improve from 2.30288
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.0675 - loss: 4.0057 - val_accuracy: 0.1027 - val_loss: 2.9683 - learning_rate: 0.0010
# Epoch 2/20
# 56/57 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2143 - loss: 2.5643
# Epoch 2: val_loss did not improve from 2.30288
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.2141 - loss: 2.5650 - val_accuracy: 0.1288 - val_loss: 3.1117 - learning_rate: 0.0010
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3059 - loss: 2.2987
# Epoch 3: val_loss did not improve from 2.30288
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.3057 - loss: 2.2992 - val_accuracy: 0.1271 - val_loss: 3.1190 - learning_rate: 0.0010
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.0975 - loss: 2.9650
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.1447 - loss: 2.7293
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.2159 - loss: 2.4770
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.2420 - loss: 2.3681
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.2729 - loss: 2.2364
# Patient 3 test accuracy: 0.1803
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Patient 3 test accuracy: 0.1803
#
#
# Processing patient 4
# Loaded segmented data shape: (9026, 400, 17)
# After dropping stimulus 0, segments shape: (6608, 400, 17)
# Train X shape: (3305, 400, 12)
# Val X shape: (2209, 400, 12)
# Test X shape: (1094, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.0843 - loss: 3.5426
# Epoch 1: val_loss did not improve from 2.30288
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.0847 - loss: 3.5273 - val_accuracy: 0.1010 - val_loss: 3.2370 - learning_rate: 0.0010
# Epoch 2/20
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1977 - loss: 2.6956
# Epoch 2: val_loss did not improve from 2.30288
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.1974 - loss: 2.6957 - val_accuracy: 0.1503 - val_loss: 3.1723 - learning_rate: 0.0010
# Epoch 3/20
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2790 - loss: 2.4022
# Epoch 3: val_loss did not improve from 2.30288
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.2790 - loss: 2.4022 - val_accuracy: 0.1526 - val_loss: 3.0288 - learning_rate: 0.0010
# Epoch 1/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.0905 - loss: 2.9621
# Epoch 2/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.1365 - loss: 2.7914
# Epoch 3/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.2061 - loss: 2.5459
# Epoch 4/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.2870 - loss: 2.2985
# Epoch 5/5
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3197 - loss: 2.1473
# Patient 4 test accuracy: 0.1115
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Patient 4 test accuracy: 0.1115
#
#
# Processing patient 5
# Loaded segmented data shape: (9022, 400, 17)
# After dropping stimulus 0, segments shape: (6420, 400, 17)
# Train X shape: (3245, 400, 12)
# Val X shape: (2146, 400, 12)
# Test X shape: (1029, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  98/102 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0911 - loss: 3.6880
# Epoch 1: val_loss did not improve from 2.30288
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.0916 - loss: 3.6642 - val_accuracy: 0.0862 - val_loss: 3.0048 - learning_rate: 0.0010
# Epoch 2/20
# 100/102 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2163 - loss: 2.5930
# Epoch 2: val_loss did not improve from 2.30288
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.2170 - loss: 2.5922 - val_accuracy: 0.1561 - val_loss: 3.3377 - learning_rate: 0.0010
# Epoch 3/20
# 100/102 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3364 - loss: 2.2064
# Epoch 3: val_loss did not improve from 2.30288
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3367 - loss: 2.2052 - val_accuracy: 0.2204 - val_loss: 3.1011 - learning_rate: 0.0010
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.1194 - loss: 2.8783
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.2513 - loss: 2.3976
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3554 - loss: 2.0729
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4732 - loss: 1.7042
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5580 - loss: 1.4226
# Patient 5 test accuracy: 0.2177
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Patient 5 test accuracy: 0.2177
#
#
# Processing patient 6
# Loaded segmented data shape: (9024, 400, 17)
# After dropping stimulus 0, segments shape: (6619, 400, 17)
# Train X shape: (3318, 400, 12)
# Val X shape: (2206, 400, 12)
# Test X shape: (1095, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0829 - loss: 3.4512
# Epoch 1: val_loss did not improve from 2.30288
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.0835 - loss: 3.4401 - val_accuracy: 0.1210 - val_loss: 2.9689 - learning_rate: 0.0010
# Epoch 2/20
# 101/104 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2182 - loss: 2.5254
# Epoch 2: val_loss did not improve from 2.30288
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.2183 - loss: 2.5242 - val_accuracy: 0.1863 - val_loss: 2.7675 - learning_rate: 0.0010
# Epoch 3/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3202 - loss: 2.1250
# Epoch 3: val_loss improved from 2.30288 to 2.29502, saving model to best_model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.3201 - loss: 2.1250 - val_accuracy: 0.2738 - val_loss: 2.2950 - learning_rate: 0.0010
# Epoch 4/20
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4321 - loss: 1.7711
# Epoch 4: val_loss improved from 2.29502 to 2.03167, saving model to best_model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4319 - loss: 1.7710 - val_accuracy: 0.3291 - val_loss: 2.0317 - learning_rate: 0.0010
# Epoch 5/20
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5346 - loss: 1.4849
# Epoch 5: val_loss improved from 2.03167 to 1.93554, saving model to best_model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5344 - loss: 1.4848 - val_accuracy: 0.3540 - val_loss: 1.9355 - learning_rate: 0.0010
# Epoch 6/20
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6119 - loss: 1.2429
# Epoch 6: val_loss did not improve from 1.93554
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.6117 - loss: 1.2434 - val_accuracy: 0.3522 - val_loss: 2.0180 - learning_rate: 0.0010
# Epoch 7/20
# 102/104 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6479 - loss: 1.1047
# Epoch 7: val_loss did not improve from 1.93554
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6478 - loss: 1.1049 - val_accuracy: 0.3590 - val_loss: 2.0858 - learning_rate: 0.0010
# Epoch 8/20
# 103/104 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7080 - loss: 0.9800
# Epoch 8: val_loss did not improve from 1.93554
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7082 - loss: 0.9792 - val_accuracy: 0.3862 - val_loss: 1.9876 - learning_rate: 5.0000e-04
# Epoch 1/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.2538 - loss: 2.3395
# Epoch 2/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.3949 - loss: 1.7630
# Epoch 3/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4917 - loss: 1.4485
# Epoch 4/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5791 - loss: 1.2905
# Epoch 5/5
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6260 - loss: 1.1084
# Patient 6 test accuracy: 0.3726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Patient 6 test accuracy: 0.3726
#
#
# Processing patient 7
# Loaded segmented data shape: (8807, 400, 17)
# After dropping stimulus 0, segments shape: (6457, 400, 17)
# Train X shape: (3239, 400, 12)
# Val X shape: (2158, 400, 12)
# Test X shape: (1060, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.0579 - loss: 3.4655
# Epoch 1: val_loss did not improve from 1.93554
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.0579 - loss: 3.4623 - val_accuracy: 0.0524 - val_loss: 3.2119 - learning_rate: 0.0010
# Epoch 2/20
# 100/102 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.1066 - loss: 2.8490
# Epoch 2: val_loss did not improve from 1.93554
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.1065 - loss: 2.8494 - val_accuracy: 0.0477 - val_loss: 3.2822 - learning_rate: 0.0010
# Epoch 3/20
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1404 - loss: 2.7291
# Epoch 3: val_loss did not improve from 1.93554
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.1401 - loss: 2.7296 - val_accuracy: 0.0598 - val_loss: 3.0844 - learning_rate: 0.0010
# Epoch 1/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.0573 - loss: 2.9856
# Epoch 2/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.0521 - loss: 2.9468
# Epoch 3/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0739 - loss: 2.9072
# Epoch 4/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0815 - loss: 2.8790
# Epoch 5/5
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0719 - loss: 2.8652
# Patient 7 test accuracy: 0.0651
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Patient 7 test accuracy: 0.0651
#
#
# Processing patient 8
# Loaded segmented data shape: (8802, 400, 17)
# After dropping stimulus 0, segments shape: (3865, 400, 17)
# Train X shape: (1926, 400, 12)
# Val X shape: (1304, 400, 12)
# Test X shape: (635, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1182 - loss: 3.6260
# Epoch 1: val_loss did not improve from 1.93554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.1184 - loss: 3.6178 - val_accuracy: 0.0690 - val_loss: 2.9772 - learning_rate: 0.0010
# Epoch 2/20
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2384 - loss: 2.4079
# Epoch 2: val_loss did not improve from 1.93554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.2390 - loss: 2.4062 - val_accuracy: 0.2086 - val_loss: 2.8551 - learning_rate: 0.0010
# Epoch 3/20
# 59/61 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3804 - loss: 2.0091
# Epoch 3: val_loss did not improve from 1.93554
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.3800 - loss: 2.0095 - val_accuracy: 0.2155 - val_loss: 2.8818 - learning_rate: 0.0010
# Epoch 1/5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.1371 - loss: 2.7480
# Epoch 2/5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2101 - loss: 2.4614
# Epoch 3/5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3272 - loss: 2.0805
# Epoch 4/5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3962 - loss: 1.8852
# Epoch 5/5
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.4738 - loss: 1.6250
# Patient 8 test accuracy: 0.2362
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Patient 8 test accuracy: 0.2362
#
#
# Processing patient 9
# Loaded segmented data shape: (8809, 400, 17)
# After dropping stimulus 0, segments shape: (4965, 400, 17)
# Train X shape: (2501, 400, 12)
# Val X shape: (1695, 400, 12)
# Test X shape: (769, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.1213 - loss: 3.6097
# Epoch 1: val_loss did not improve from 1.93554
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.1215 - loss: 3.6031 - val_accuracy: 0.2283 - val_loss: 2.6423 - learning_rate: 0.0010
# Epoch 2/20
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2707 - loss: 2.3379
# Epoch 2: val_loss did not improve from 1.93554
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.2718 - loss: 2.3350 - val_accuracy: 0.2749 - val_loss: 2.6254 - learning_rate: 0.0010
# Epoch 3/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4010 - loss: 1.8881
# Epoch 3: val_loss did not improve from 1.93554
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.4010 - loss: 1.8881 - val_accuracy: 0.3133 - val_loss: 2.4432 - learning_rate: 0.0010
# Epoch 1/5
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1902 - loss: 2.6756
# Epoch 2/5
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3425 - loss: 2.0953
# Epoch 3/5
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.4429 - loss: 1.7264
# Epoch 4/5
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5056 - loss: 1.4826
# Epoch 5/5
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5861 - loss: 1.3287
# Patient 9 test accuracy: 0.3459
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Patient 9 test accuracy: 0.3459
#
#
# Processing patient 10
# Loaded segmented data shape: (8798, 400, 17)
# After dropping stimulus 0, segments shape: (6343, 400, 17)
# Train X shape: (3202, 400, 12)
# Val X shape: (2100, 400, 12)
# Test X shape: (1041, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0700 - loss: 3.6062
# Epoch 1: val_loss did not improve from 1.93554
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.0701 - loss: 3.6019 - val_accuracy: 0.0667 - val_loss: 3.6512 - learning_rate: 0.0010
# Epoch 2/20
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.1664 - loss: 2.7168
# Epoch 2: val_loss did not improve from 1.93554
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.1668 - loss: 2.7164 - val_accuracy: 0.1224 - val_loss: 3.2545 - learning_rate: 0.0010
# Epoch 3/20
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2521 - loss: 2.4477
# Epoch 3: val_loss did not improve from 1.93554
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.2524 - loss: 2.4477 - val_accuracy: 0.1800 - val_loss: 2.7546 - learning_rate: 0.0010
# Epoch 1/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.0946 - loss: 2.9305
# Epoch 2/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.1769 - loss: 2.6953
# Epoch 3/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.2369 - loss: 2.4162
# Epoch 4/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3077 - loss: 2.1630
# Epoch 5/5
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.3740 - loss: 1.9667
# Patient 10 test accuracy: 0.1633
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Patient 10 test accuracy: 0.1633
#
#
# Processing patient 11
# Loaded segmented data shape: (8862, 400, 17)
# After dropping stimulus 0, segments shape: (3947, 400, 17)
# Train X shape: (2053, 400, 12)
# Val X shape: (1252, 400, 12)
# Test X shape: (642, 400, 12)
# Initializing model with input shape: (400, 12)
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 62/65 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.1232 - loss: 3.7704
# Epoch 1: val_loss did not improve from 1.93554
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.1246 - loss: 3.7342 - val_accuracy: 0.1470 - val_loss: 2.9701 - learning_rate: 0.0010
# Epoch 2/20
# 62/65 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3152 - loss: 2.2418
# Epoch 2: val_loss did not improve from 1.93554
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.3172 - loss: 2.2374 - val_accuracy: 0.2404 - val_loss: 2.8840 - learning_rate: 0.0010
# Epoch 3/20
# 61/65 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4893 - loss: 1.6093
# Epoch 3: val_loss did not improve from 1.93554
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4889 - loss: 1.6140 - val_accuracy: 0.2891 - val_loss: 2.7533 - learning_rate: 0.0010
# Epoch 1/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.1649 - loss: 2.7798
# Epoch 2/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3276 - loss: 2.1950
# Epoch 3/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4558 - loss: 1.7690
# Epoch 4/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5529 - loss: 1.4451
# Epoch 5/5
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6475 - loss: 1.1829
# Patient 11 test accuracy: 0.3956
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Patient 11 test accuracy: 0.3956
#
# Processing complete for all patients.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Convert results list to a DataFrame.
results_df = pd.DataFrame(results)
print(results_df.columns)  # For debugging, check column names

# Plot Accuracy vs. Years Since Amputation
plt.figure(figsize=(10, 6))
plt.scatter(results_df['Years_Since_Amputation'], results_df['TestAccuracy'], c='blue', label='Accuracy')

# Best fit line
coeffs = np.polyfit(results_df['Years_Since_Amputation'], results_df['TestAccuracy'], deg=1)
line = np.poly1d(coeffs)
x_vals = np.linspace(results_df['Years_Since_Amputation'].min(), results_df['Years_Since_Amputation'].max(), 100)
plt.plot(x_vals, line(x_vals), color='blue', label='Best Fit Line')

plt.xlabel('Years Since Amputation')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy vs. Years Since Amputation')
plt.grid(True)
plt.legend()
plt.show()

# Plot Accuracy vs. Forearm Percentage
plt.figure(figsize=(10, 6))
plt.scatter(results_df['Forearm_Percentage'], results_df['TestAccuracy'], c='green', label='Accuracy')

# Best fit line
coeffs = np.polyfit(results_df['Forearm_Percentage'], results_df['TestAccuracy'], deg=1)
line = np.poly1d(coeffs)
x_vals = np.linspace(results_df['Forearm_Percentage'].min(), results_df['Forearm_Percentage'].max(), 100)
plt.plot(x_vals, line(x_vals), color='green', label='Best Fit Line')

plt.xlabel('Forearm Percentage')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy vs. Forearm Percentage')
plt.grid(True)
plt.legend()
plt.show()

# Plot Accuracy vs. Myoelectric Use
plt.figure(figsize=(10, 6))
plt.scatter(results_df['Myoelectric_Use'], results_df['TestAccuracy'], c='red', label='Accuracy')

# Best fit line
coeffs = np.polyfit(results_df['Myoelectric_Use'], results_df['TestAccuracy'], deg=1)
line = np.poly1d(coeffs)
x_vals = np.linspace(results_df['Myoelectric_Use'].min(), results_df['Myoelectric_Use'].max(), 100)
plt.plot(x_vals, line(x_vals), color='red', label='Best Fit Line')

plt.xlabel('Myoelectric Use')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy vs. Myoelectric Use')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Index(['PatientID', 'TestAccuracy', 'Years_Since_Amputation',
#        'Forearm_Percentage', 'Myoelectric_Use'],
#       dtype='object')

# %%
import scipy.stats as stats
import statsmodels.api as sm

# Statistical analysis function
def analyze_relationship(x, y, variable_name):
    # Pearson correlation
    r, p_value_corr = stats.pearsonr(x, y)
    
    # Linear Regression Analysis
    X = sm.add_constant(x)  # Add constant for intercept
    model = sm.OLS(y, X).fit()
    p_value_reg = model.pvalues[1]  # p-value for the predictor variable
    
    print(f"\nAnalysis for {variable_name}:")
    print(f"Pearson Correlation: r = {r:.4f}, p-value = {p_value_corr:.4f}")
    print(f"Linear Regression: Coefficient = {model.params[1]:.4f}, p-value = {p_value_reg:.4f}")
    
    if p_value_corr < 0.05:
        print(f"→ The correlation between {variable_name} and Accuracy is statistically significant (p < 0.05).")
    else:
        print(f"→ No significant correlation found (p >= 0.05).")
    
    if p_value_reg < 0.05:
        print(f"→ The regression model suggests a significant effect of {variable_name} on Accuracy (p < 0.05).")
    else:
        print(f"→ No significant effect found in regression (p >= 0.05).")

# Assuming results_df is your DataFrame with columns: 'Years_Since_Amputation', 
# 'Forearm_Percentage', 'Myoelectric_Use', and 'TestAccuracy'
analyze_relationship(results_df['Years_Since_Amputation'], results_df['TestAccuracy'], "Years Since Amputation")
analyze_relationship(results_df['Forearm_Percentage'], results_df['TestAccuracy'], "Forearm Percentage")
analyze_relationship(results_df['Myoelectric_Use'], results_df['TestAccuracy'], "Myoelectric Use")
# Out:
# Analysis for Years Since Amputation:
# Pearson Correlation: r = 0.5932, p-value = 0.0544
# Linear Regression: Coefficient = 0.0139, p-value = 0.0544
# → No significant correlation found (p >= 0.05).
# → No significant effect found in regression (p >= 0.05).
#
# Analysis for Forearm Percentage:
# Pearson Correlation: r = 0.6496, p-value = 0.0305
# Linear Regression: Coefficient = 0.2565, p-value = 0.0305
# → The correlation between Forearm Percentage and Accuracy is statistically significant (p < 0.05).
# → The regression model suggests a significant effect of Forearm Percentage on Accuracy (p < 0.05).
#
# Analysis for Myoelectric Use:
# Pearson Correlation: r = 0.2469, p-value = 0.4642
# Linear Regression: Coefficient = 0.0052, p-value = 0.4642
# → No significant correlation found (p >= 0.05).
# → No significant effect found in regression (p >= 0.05).
# /var/folders/2v/6zvn9f795zd164wfvwjybwqr0000gn/T/ipykernel_88460/4168042512.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_reg = model.pvalues[1]  # p-value for the predictor variable
# /var/folders/2v/6zvn9f795zd164wfvwjybwqr0000gn/T/ipykernel_88460/4168042512.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Linear Regression: Coefficient = {model.params[1]:.4f}, p-value = {p_value_reg:.4f}")
# /var/folders/2v/6zvn9f795zd164wfvwjybwqr0000gn/T/ipykernel_88460/4168042512.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_reg = model.pvalues[1]  # p-value for the predictor variable
# /var/folders/2v/6zvn9f795zd164wfvwjybwqr0000gn/T/ipykernel_88460/4168042512.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Linear Regression: Coefficient = {model.params[1]:.4f}, p-value = {p_value_reg:.4f}")
# /var/folders/2v/6zvn9f795zd164wfvwjybwqr0000gn/T/ipykernel_88460/4168042512.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_reg = model.pvalues[1]  # p-value for the predictor variable
# /var/folders/2v/6zvn9f795zd164wfvwjybwqr0000gn/T/ipykernel_88460/4168042512.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Linear Regression: Coefficient = {model.params[1]:.4f}, p-value = {p_value_reg:.4f}")
